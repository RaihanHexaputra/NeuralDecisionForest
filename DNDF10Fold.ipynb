# %%
pip install pefile==2019.4.18
# Out:
# Requirement already satisfied: pefile==2019.4.18 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (2019.4.18)
# Requirement already satisfied: future in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from pefile==2019.4.18) (0.18.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pefile==2019.4.18
# Out:
# Requirement already satisfied: pefile==2019.4.18 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (2019.4.18)
# Requirement already satisfied: future in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from pefile==2019.4.18) (0.18.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install -U scikit-learn scipy matplotlib
# Out:
# Requirement already satisfied: scikit-learn in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (1.3.2)
# Requirement already satisfied: scipy in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (1.11.4)
# Requirement already satisfied: matplotlib in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (3.8.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.56.2)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.41.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\muhammad raihan\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Library
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy
import pickle
import pefile
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
import joblib
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
import sklearn.metrics as metrics
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_score
import time
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Input Dataset 

DM = pd.read_csv("C:\\Users\\Muhammad Raihan\\Downloads\\Obfuscated-MalMem2022.csv") #DM--> Dataset Malware

# %%
# Menapilkan head (5 Data Teratas)

DM.head()
# Out:
#   Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# 0   Benign            45            17           10.555556
# 1   Benign            47            19           11.531915
# 2   Benign            40            14           14.725000
# 3   Benign            32            13           13.500000
# 4   Benign            42            16           11.452381
#
#    pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# 0                   0           202.844444           1694
# 1                   0           242.234043           2074
# 2                   0           288.225000           1932
# 3                   0           264.281250           1445
# 4                   0           281.333333           2067
#
#    dlllist.avg_dlls_per_proc  handles.nhandles  handles.avg_handles_per_proc  \
# 0                  38.500000              9129                    212.302326
# 1                  44.127660             11385                    242.234043
# 2                  48.300000             11529                    288.225000
# 3                  45.156250              8457                    264.281250
# 4                  49.214286             11816                    281.333333
#
#    ...  svcscan.kernel_drivers  svcscan.fs_drivers  svcscan.process_services  \
# 0  ...                     221                  26                        24
# 1  ...                     222                  26                        24
# 2  ...                     222                  26                        27
# 3  ...                     222                  26                        27
# 4  ...                     222                  26                        24
#
#    svcscan.shared_process_services  svcscan.interactive_process_services  \
# 0                              116                                     0
# 1                              118                                     0
# 2                              118                                     0
# 3                              118                                     0
# 4                              118                                     0
#
#    svcscan.nactive  callbacks.ncallbacks  callbacks.nanonymous  \
# 0              121                    87                     0
# 1              122                    87                     0
# 2              120                    88                     0
# 3              120                    88                     0
# 4              124                    87                     0
#
#    callbacks.ngeneric   Class
# 0                   8  Benign
# 1                   8  Benign
# 2                   8  Benign
# 3                   8  Benign
# 4                   8  Benign
#
# [5 rows x 57 columns]

# %%
# Menampilkan Tail (5 Data Terbawah)

DM.tail()
# Out:
#                                                 Category  pslist.nproc  \
# 58591  Ransomware-Shade-fa03be3078d1b9840f06745f160eb...            37
# 58592  Ransomware-Shade-f56687137caf9a67678cde91e4614...            37
# 58593  Ransomware-Shade-faddeea111a25da4d0888f3044ae9...            38
# 58594  Ransomware-Shade-f866c086af2e1d8ebaa6f2c863157...            37
# 58595  Ransomware-Shade-955d9af38346c1755527bd196668e...            38
#
#        pslist.nppid  pslist.avg_threads  pslist.nprocs64bit  \
# 58591            15           10.108108                   0
# 58592            14            9.945946                   0
# 58593            15            9.842105                   0
# 58594            15           10.243243                   0
# 58595            15            9.868421                   0
#
#        pslist.avg_handlers  dlllist.ndlls  dlllist.avg_dlls_per_proc  \
# 58591           215.486487           1453                  39.270270
# 58592           190.216216           1347                  36.405405
# 58593           210.026316           1448                  38.105263
# 58594           215.513513           1452                  39.243243
# 58595           213.026316           1487                  39.131579
#
#        handles.nhandles  handles.avg_handles_per_proc  ...  \
# 58591              7973                    215.486487  ...
# 58592              7038                    190.216216  ...
# 58593              7982                    215.729730  ...
# 58594              7974                    215.513513  ...
# 58595              8095                    213.026316  ...
#
#        svcscan.kernel_drivers  svcscan.fs_drivers  svcscan.process_services  \
# 58591                     221                  26                        24
# 58592                     221                  26                        24
# 58593                     221                  26                        24
# 58594                     221                  26                        24
# 58595                     221                  26                        24
#
#        svcscan.shared_process_services  svcscan.interactive_process_services  \
# 58591                              116                                     0
# 58592                              116                                     0
# 58593                              116                                     0
# 58594                              116                                     0
# 58595                              116                                     0
#
#        svcscan.nactive  callbacks.ncallbacks  callbacks.nanonymous  \
# 58591              120                    86                     0
# 58592              116                    88                     0
# 58593              120                    88                     0
# 58594              120                    87                     0
# 58595              120                    86                     0
#
#        callbacks.ngeneric    Class
# 58591                   8  Malware
# 58592                   8  Malware
# 58593                   8  Malware
# 58594                   8  Malware
# 58595                   8  Malware
#
# [5 rows x 57 columns]

# %%
# Menampilkan Kesimpulan Atribut Numerik

DM.describe(include="all")
# Out:
#        Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# count     58596  58596.000000  58596.000000        58596.000000
# unique    28346           NaN           NaN                 NaN
# top      Benign           NaN           NaN                 NaN
# freq      29298           NaN           NaN                 NaN
# mean        NaN     41.394771     14.713837           11.341655
# std         NaN      5.777249      2.656748            1.588231
# min         NaN     21.000000      8.000000            1.650000
# 25%         NaN     40.000000     12.000000            9.972973
# 50%         NaN     41.000000     15.000000           11.000000
# 75%         NaN     43.000000     16.000000           12.861955
# max         NaN    240.000000     72.000000           16.818182
#
#         pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# count              58596.0         58596.000000   58596.000000
# unique                 NaN                  NaN            NaN
# top                    NaN                  NaN            NaN
# freq                   NaN                  NaN            NaN
# mean                   0.0           247.509819    1810.805447
# std                    0.0           111.857790     329.782639
# min                    0.0            34.962500     670.000000
# 25%                    0.0           208.725000    1556.000000
# 50%                    0.0           243.963710    1735.000000
# 75%                    0.0           289.974322    2087.000000
# max                    0.0         24845.951220    3443.000000
#
#         dlllist.avg_dlls_per_proc  handles.nhandles  \
# count                58596.000000      5.859600e+04
# unique                        NaN               NaN
# top                           NaN               NaN
# freq                          NaN               NaN
# mean                    43.707806      1.025858e+04
# std                      5.742023      4.866864e+03
# min                      7.333333      3.514000e+03
# 25%                     38.833333      8.393000e+03
# 50%                     42.781524      9.287500e+03
# 75%                     49.605280      1.219300e+04
# max                     53.170732      1.047310e+06
#
#         handles.avg_handles_per_proc  ...  svcscan.kernel_drivers  \
# count                   58596.000000  ...            58596.000000
# unique                           NaN  ...                     NaN
# top                              NaN  ...                     NaN
# freq                             NaN  ...                     NaN
# mean                      249.560958  ...              221.406581
# std                       145.999866  ...                1.991087
# min                        71.139241  ...               55.000000
# 25%                       209.648228  ...              221.000000
# 50%                       247.208951  ...              221.000000
# 75%                       291.355050  ...              222.000000
# max                     33784.193550  ...              222.000000
#
#         svcscan.fs_drivers  svcscan.process_services  \
# count         58596.000000              58596.000000
# unique                 NaN                       NaN
# top                    NaN                       NaN
# freq                   NaN                       NaN
# mean             25.996245                 25.063417
# std               0.170790                  1.529628
# min               6.000000                  7.000000
# 25%              26.000000                 24.000000
# 50%              26.000000                 24.000000
# 75%              26.000000                 27.000000
# max              26.000000                 27.000000
#
#         svcscan.shared_process_services  svcscan.interactive_process_services  \
# count                      58596.000000                               58596.0
# unique                              NaN                                   NaN
# top                                 NaN                                   NaN
# freq                                NaN                                   NaN
# mean                         116.879514                                   0.0
# std                            1.550401                                   0.0
# min                           26.000000                                   0.0
# 25%                          116.000000                                   0.0
# 50%                          116.000000                                   0.0
# 75%                          118.000000                                   0.0
# max                          118.000000                                   0.0
#
#         svcscan.nactive  callbacks.ncallbacks  callbacks.nanonymous  \
# count      58596.000000          58596.000000          58596.000000
# unique              NaN                   NaN                   NaN
# top                 NaN                   NaN                   NaN
# freq                NaN                   NaN                   NaN
# mean         121.995546             86.905659              0.000853
# std            2.822858              3.134117              0.029199
# min           30.000000             50.000000              0.000000
# 25%          121.000000             87.000000              0.000000
# 50%          122.000000             87.000000              0.000000
# 75%          123.000000             88.000000              0.000000
# max          129.000000             89.000000              1.000000
#
#         callbacks.ngeneric   Class
# count         58596.000000   58596
# unique                 NaN       2
# top                    NaN  Benign
# freq                   NaN   29298
# mean              7.999881     NaN
# std               0.010929     NaN
# min               7.000000     NaN
# 25%               8.000000     NaN
# 50%               8.000000     NaN
# 75%               8.000000     NaN
# max               8.000000     NaN
#
# [11 rows x 57 columns]

# %%
# Menampilkan Kesimpulan Atribut Numerik

DM.describe(include="all")
# Out:
#        Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# count     58596  58596.000000  58596.000000        58596.000000
# unique    28346           NaN           NaN                 NaN
# top      Benign           NaN           NaN                 NaN
# freq      29298           NaN           NaN                 NaN
# mean        NaN     41.394771     14.713837           11.341655
# std         NaN      5.777249      2.656748            1.588231
# min         NaN     21.000000      8.000000            1.650000
# 25%         NaN     40.000000     12.000000            9.972973
# 50%         NaN     41.000000     15.000000           11.000000
# 75%         NaN     43.000000     16.000000           12.861955
# max         NaN    240.000000     72.000000           16.818182
#
#         pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# count              58596.0         58596.000000   58596.000000
# unique                 NaN                  NaN            NaN
# top                    NaN                  NaN            NaN
# freq                   NaN                  NaN            NaN
# mean                   0.0           247.509819    1810.805447
# std                    0.0           111.857790     329.782639
# min                    0.0            34.962500     670.000000
# 25%                    0.0           208.725000    1556.000000
# 50%                    0.0           243.963710    1735.000000
# 75%                    0.0           289.974322    2087.000000
# max                    0.0         24845.951220    3443.000000
#
#         dlllist.avg_dlls_per_proc  handles.nhandles  \
# count                58596.000000      5.859600e+04
# unique                        NaN               NaN
# top                           NaN               NaN
# freq                          NaN               NaN
# mean                    43.707806      1.025858e+04
# std                      5.742023      4.866864e+03
# min                      7.333333      3.514000e+03
# 25%                     38.833333      8.393000e+03
# 50%                     42.781524      9.287500e+03
# 75%                     49.605280      1.219300e+04
# max                     53.170732      1.047310e+06
#
#         handles.avg_handles_per_proc  ...  svcscan.kernel_drivers  \
# count                   58596.000000  ...            58596.000000
# unique                           NaN  ...                     NaN
# top                              NaN  ...                     NaN
# freq                             NaN  ...                     NaN
# mean                      249.560958  ...              221.406581
# std                       145.999866  ...                1.991087
# min                        71.139241  ...               55.000000
# 25%                       209.648228  ...              221.000000
# 50%                       247.208951  ...              221.000000
# 75%                       291.355050  ...              222.000000
# max                     33784.193550  ...              222.000000
#
#         svcscan.fs_drivers  svcscan.process_services  \
# count         58596.000000              58596.000000
# unique                 NaN                       NaN
# top                    NaN                       NaN
# freq                   NaN                       NaN
# mean             25.996245                 25.063417
# std               0.170790                  1.529628
# min               6.000000                  7.000000
# 25%              26.000000                 24.000000
# 50%              26.000000                 24.000000
# 75%              26.000000                 27.000000
# max              26.000000                 27.000000
#
#         svcscan.shared_process_services  svcscan.interactive_process_services  \
# count                      58596.000000                               58596.0
# unique                              NaN                                   NaN
# top                                 NaN                                   NaN
# freq                                NaN                                   NaN
# mean                         116.879514                                   0.0
# std                            1.550401                                   0.0
# min                           26.000000                                   0.0
# 25%                          116.000000                                   0.0
# 50%                          116.000000                                   0.0
# 75%                          118.000000                                   0.0
# max                          118.000000                                   0.0
#
#         svcscan.nactive  callbacks.ncallbacks  callbacks.nanonymous  \
# count      58596.000000          58596.000000          58596.000000
# unique              NaN                   NaN                   NaN
# top                 NaN                   NaN                   NaN
# freq                NaN                   NaN                   NaN
# mean         121.995546             86.905659              0.000853
# std            2.822858              3.134117              0.029199
# min           30.000000             50.000000              0.000000
# 25%          121.000000             87.000000              0.000000
# 50%          122.000000             87.000000              0.000000
# 75%          123.000000             88.000000              0.000000
# max          129.000000             89.000000              1.000000
#
#         callbacks.ngeneric   Class
# count         58596.000000   58596
# unique                 NaN       2
# top                    NaN  Benign
# freq                   NaN   29298
# mean              7.999881     NaN
# std               0.010929     NaN
# min               7.000000     NaN
# 25%               8.000000     NaN
# 50%               8.000000     NaN
# 75%               8.000000     NaN
# max               8.000000     NaN
#
# [11 rows x 57 columns]

# %%
DM["Class"].value_counts()
# Out:
# Benign     29298
# Malware    29298
# Name: Class, dtype: int64

# %%
#Visualisasi

DM["Class"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.show()

# %%
#Feature Selection
X = DM.drop(['Category','Class'],axis=1).values    #Droping this because classification model will not accept object type elements (float and int only)
# Target variable
y = DM['Class'].values

# %%
#Data Fitting and choosing the important variables
extratrees = ek.ExtraTreesClassifier().fit(X,y)
model = SelectFromModel(extratrees, prefit=True)
X_new = model.transform(X)
nbfeatures = X_new.shape[1]

# %%
#Number of important features
nbfeatures
# Out:
# 18

# %%
features = []
index = numpy.argsort(extratrees.feature_importances_)[::-1][:nbfeatures]

# %%
#All the required features
for f in range(nbfeatures):
    print("%d. feature %s (%f)" % (f + 1, DM.columns[2+index[f]], extratrees.feature_importances_[index[f]]))
    features.append(DM.columns[2+f])
# Out:
# 1. feature ldrmodules.not_in_load (0.091925)
# 2. feature handles.ndesktop (0.079972)
# 3. feature handles.nhandles (0.072527)
# 4. feature svcscan.shared_process_services (0.072477)
# 5. feature ldrmodules.not_in_init (0.061844)
# 6. feature svcscan.interactive_process_services (0.057857)
# 7. feature pslist.nprocs64bit (0.050282)
# 8. feature svcscan.kernel_drivers (0.044395)
# 9. feature handles.ndirectory (0.043307)
# 10. feature dlllist.avg_dlls_per_proc (0.042691)
# 11. feature svcscan.fs_drivers (0.039603)
# 12. feature handles.nthread (0.032691)
# 13. feature ldrmodules.not_in_load_avg (0.031961)
# 14. feature callbacks.ncallbacks (0.028176)
# 15. feature ldrmodules.not_in_mem (0.026963)
# 16. feature handles.nsection (0.024403)
# 17. feature handles.nport (0.024088)
# 18. feature handles.ntimer (0.018784)

# %%
class NeuralDecisionTree(keras.Model):
    def __init__(self, depth, num_features, used_features_rate, num_classes):
        super().__init__()
        self.depth = depth
        self.num_leaves = 2 ** depth
        self.num_classes = num_classes

        # Create a mask for the randomly selected features.
        num_used_features = int(num_features * used_features_rate)
        one_hot = np.eye(num_features)
        sampled_feature_indicies = np.random.choice(
            np.arange(num_features), num_used_features, replace=False
        )
        self.used_features_mask = one_hot[sampled_feature_indicies]

        # Initialize the weights of the classes in leaves.
        self.pi = tf.Variable(
            initial_value=tf.random_normal_initializer()(
                shape=[self.num_leaves, self.num_classes]
            ),
            dtype="float32",
            trainable=True,
        )

        # Initialize the stochastic routing layer.
        self.decision_fn = layers.Dense(
            units=self.num_leaves, activation="sigmoid", name="decision"
        )

    def call(self, features):
        batch_size = tf.shape(features)[0]

        # Apply the feature mask to the input features.
        features = tf.matmul(
            features, self.used_features_mask, transpose_b=True
        )  # [batch_size, num_used_features]
        # Compute the routing probabilities.
        decisions = tf.expand_dims(
            self.decision_fn(features), axis=2
        )  # [batch_size, num_leaves, 1]
        # Concatenate the routing probabilities with their complements.
        decisions = layers.concatenate(
            [decisions, 1 - decisions], axis=2
        )  # [batch_size, num_leaves, 2]

        mu = tf.ones([batch_size, 1, 1])

        begin_idx = 1
        end_idx = 2
        # Traverse the tree in breadth-first order.
        for level in range(self.depth):
            mu = tf.reshape(mu, [batch_size, -1, 1])  # [batch_size, 2 ** level, 1]
            mu = tf.tile(mu, (1, 1, 2))  # [batch_size, 2 ** level, 2]
            level_decisions = decisions[
                :, begin_idx:end_idx, :
            ]  # [batch_size, 2 ** level, 2]
            mu = mu * level_decisions  # [batch_size, 2**level, 2]
            begin_idx = end_idx
            end_idx = begin_idx + 2 ** (level + 1)

        mu = tf.reshape(mu, [batch_size, self.num_leaves])  # [batch_size, num_leaves]
        probabilities = keras.activations.softmax(self.pi)  # [num_leaves, num_classes]
        outputs = tf.matmul(mu, probabilities)  # [batch_size, num_classes]
        return outputs

# %%
class NeuralDecisionForest(keras.Model):
    def __init__(self, num_trees, depth, num_features, used_features_rate, num_classes):
        super().__init__()
        self.ensemble = []
        # Initialize the ensemble by adding NeuralDecisionForest instances.
        # Each tree will have its own randomly selected input features to use.
        for _ in range(num_trees):
            self.ensemble.append(
                NeuralDecisionTree(depth, num_features, used_features_rate, num_classes)
            )

    def call(self, inputs):
        # Initialize the outputs: a [batch_size, num_classes] matrix of zeros.
        batch_size = tf.shape(inputs)[0]
        outputs = tf.zeros([batch_size, num_classes])

        # Aggregate the outputs of trees in the ensemble.
        for tree in self.ensemble:
            outputs += tree(inputs)
        # Divide the outputs by the ensemble size to get the average.
        outputs /= len(self.ensemble)
        return outputs

# %%
class NeuralDecisionForest(keras.Model):
    def __init__(self, num_trees, depth, num_features, used_features_rate, num_classes):
        super().__init__()
        self.ensemble = []
        # Initialize the ensemble by adding NeuralDecisionForest instances.
        # Each tree will have its own randomly selected input features to use.
        for _ in range(num_trees):
            self.ensemble.append(
                NeuralDecisionTree(depth, num_features, used_features_rate, num_classes)
            )

    def call(self, inputs):
        # Initialize the outputs: a [batch_size, num_classes] matrix of zeros.
        batch_size = tf.shape(inputs)[0]
        outputs = tf.zeros([batch_size, num_classes])

        # Aggregate the outputs of trees in the ensemble.
        for tree in self.ensemble:
            outputs += tree(inputs)
        # Divide the outputs by the ensemble size to get the average.
        outputs /= len(self.ensemble)
        return outputs

# %%
# Assuming 'DM' is your DataFrame
X = DM[features]
y = (DM['Class'] == 'Malware').astype(int)

# Convert y to a 1D array and make sure it's an integer array
y = y.values.astype(int)

# Define the number of folds
num_folds = 10
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
learning_rate = 0.01
num_classes = 2  # Assuming binary classification (malware or not)
batch_size = 265
num_epochs = 100
num_trees = 25
depth = 5
used_features_rate = 0.5

# Function to create the forest model
def create_forest_model():
    input_shape = X.shape[1]
    inputs = layers.Input(shape=(input_shape,))
    normalized_inputs = layers.BatchNormalization()(inputs)

    forest_model = NeuralDecisionForest(
        num_trees, depth, input_shape, used_features_rate, num_classes=num_classes
    )

    outputs = forest_model(normalized_inputs)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# Function to run the experiment with cross-validation
def run_experiment_with_cv(model, X, y, skf):
    fold_results = []

    for fold, (train_index, test_index) in enumerate(skf.split(X, y), 1):
        print(f"\nFold {fold}:")

        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
            loss=keras.losses.SparseCategoricalCrossentropy(),
            metrics=[keras.metrics.SparseCategoricalAccuracy()],
        )

        print("Start training the model...")
        start_time = time.time()
        model.fit(X_train, y_train, epochs=num_epochs, batch_size=batch_size, validation_split=0.2)
        end_time = time.time()
        print("Model training finished")

        print("Evaluating the model on the test data...")
        _, accuracy = model.evaluate(X_test, y_test)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        y_test = y_test.astype(int)
        y_pred = np.argmax(model.predict(X_test), axis=1)

        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")

        training_time = end_time - start_time
        print("Total Training Time:", training_time, "seconds")

        fold_results.append({
            "fold": fold,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "training_time": training_time,
        })

    return fold_results

# Run the experiment with cross-validation
results = run_experiment_with_cv(create_forest_model(), X, y, skf)

# Display average performance metrics across all folds
avg_accuracy = np.mean([result["accuracy"] for result in results])
avg_precision = np.mean([result["precision"] for result in results])
avg_recall = np.mean([result["recall"] for result in results])
avg_f1 = np.mean([result["f1"] for result in results])
avg_training_time = np.mean([result["training_time"] for result in results])

print("\nAverage Performance Metrics Across Folds:")
print(f"Average Accuracy: {avg_accuracy:.4f}")
print(f"Average Precision: {avg_precision:.4f}")
print(f"Average Recall: {avg_recall:.4f}")
print(f"Average F1 Score: {avg_f1:.4f}")
print(f"Average Training Time: {avg_training_time:.4f} seconds")
# Out:
# Fold 1:
# Start training the model...
# Epoch 1/100
# 160/160 [==============================] - 14s 15ms/step - loss: 0.2494 - sparse_categorical_accuracy: 0.9815 - val_loss: 2.3788 - val_sparse_categorical_accuracy: 0.0495
# Epoch 2/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0505 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.1354 - val_sparse_categorical_accuracy: 0.9876
# Epoch 3/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0303 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0369 - val_sparse_categorical_accuracy: 0.9945
# Epoch 4/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0287 - val_sparse_categorical_accuracy: 0.9953
# Epoch 5/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0180 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0259 - val_sparse_categorical_accuracy: 0.9973
# Epoch 6/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0212 - val_sparse_categorical_accuracy: 0.9980
# Epoch 7/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0139 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 0.9982
# Epoch 8/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0123 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0199 - val_sparse_categorical_accuracy: 0.9980
# Epoch 9/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 0.9982
# Epoch 10/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 0.9982
# Epoch 11/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0143 - val_sparse_categorical_accuracy: 0.9980
# Epoch 12/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 0.9980
# Epoch 13/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 0.9982
# Epoch 14/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0104 - val_sparse_categorical_accuracy: 0.9982
# Epoch 15/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0080 - val_sparse_categorical_accuracy: 0.9985
# Epoch 16/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0103 - val_sparse_categorical_accuracy: 0.9981
# Epoch 17/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0083 - val_sparse_categorical_accuracy: 0.9983
# Epoch 18/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0074 - val_sparse_categorical_accuracy: 0.9983
# Epoch 19/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0090 - val_sparse_categorical_accuracy: 0.9981
# Epoch 20/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0088 - val_sparse_categorical_accuracy: 0.9981
# Epoch 21/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0087 - val_sparse_categorical_accuracy: 0.9982
# Epoch 22/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 0.9981
# Epoch 23/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0068 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0095 - val_sparse_categorical_accuracy: 0.9982
# Epoch 24/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 0.9982
# Epoch 25/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0102 - val_sparse_categorical_accuracy: 0.9982
# Epoch 26/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0077 - val_sparse_categorical_accuracy: 0.9983
# Epoch 27/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0092 - val_sparse_categorical_accuracy: 0.9981
# Epoch 28/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9982
# Epoch 29/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0135 - val_sparse_categorical_accuracy: 0.9982
# Epoch 30/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0110 - val_sparse_categorical_accuracy: 0.9983
# Epoch 31/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 0.9982
# Epoch 32/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 0.9983
# Epoch 33/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 0.9982
# Epoch 34/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 0.9980
# Epoch 35/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0135 - val_sparse_categorical_accuracy: 0.9982
# Epoch 36/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9982
# Epoch 37/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 0.9983
# Epoch 38/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 0.9979
# Epoch 39/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 0.9984
# Epoch 40/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0105 - val_sparse_categorical_accuracy: 0.9983
# Epoch 41/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0107 - val_sparse_categorical_accuracy: 0.9982
# Epoch 42/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 0.9982
# Epoch 43/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0135 - val_sparse_categorical_accuracy: 0.9983
# Epoch 44/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9983
# Epoch 45/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0092 - val_sparse_categorical_accuracy: 0.9984
# Epoch 46/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0131 - val_sparse_categorical_accuracy: 0.9982
# Epoch 47/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9984
# Epoch 48/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 0.9983
# Epoch 49/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0090 - val_sparse_categorical_accuracy: 0.9982
# Epoch 50/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 0.9978
# Epoch 51/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0188 - val_sparse_categorical_accuracy: 0.9980
# Epoch 52/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0148 - val_sparse_categorical_accuracy: 0.9978
# Epoch 53/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0157 - val_sparse_categorical_accuracy: 0.9977
# Epoch 54/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0145 - val_sparse_categorical_accuracy: 0.9982
# Epoch 55/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0155 - val_sparse_categorical_accuracy: 0.9977
# Epoch 56/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 0.9980
# Epoch 57/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 0.9977
# Epoch 58/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0119 - val_sparse_categorical_accuracy: 0.9980
# Epoch 59/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0150 - val_sparse_categorical_accuracy: 0.9982
# Epoch 60/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0169 - val_sparse_categorical_accuracy: 0.9980
# Epoch 61/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0192 - val_sparse_categorical_accuracy: 0.9980
# Epoch 62/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0263 - val_sparse_categorical_accuracy: 0.9977
# Epoch 63/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 0.9983
# Epoch 64/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0179 - val_sparse_categorical_accuracy: 0.9978
# Epoch 65/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 0.9980
# Epoch 66/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0253 - val_sparse_categorical_accuracy: 0.9979
# Epoch 67/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0213 - val_sparse_categorical_accuracy: 0.9981
# Epoch 68/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 0.9983
# Epoch 69/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0127 - val_sparse_categorical_accuracy: 0.9980
# Epoch 70/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9981
# Epoch 71/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0098 - val_sparse_categorical_accuracy: 0.9985
# Epoch 72/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0216 - val_sparse_categorical_accuracy: 0.9983
# Epoch 73/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0261 - val_sparse_categorical_accuracy: 0.9979
# Epoch 74/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9981
# Epoch 75/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 0.9983
# Epoch 76/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9980
# Epoch 77/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9983
# Epoch 78/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 0.9979
# Epoch 79/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 0.9980
# Epoch 80/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 0.9978
# Epoch 81/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0138 - val_sparse_categorical_accuracy: 0.9982
# Epoch 82/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 0.9979
# Epoch 83/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 0.9980
# Epoch 84/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0096 - val_sparse_categorical_accuracy: 0.9979
# Epoch 85/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 0.9980
# Epoch 86/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 0.9978
# Epoch 87/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9980
# Epoch 88/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9978
# Epoch 89/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0220 - val_sparse_categorical_accuracy: 0.9977
# Epoch 90/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0195 - val_sparse_categorical_accuracy: 0.9979
# Epoch 91/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0152 - val_sparse_categorical_accuracy: 0.9977
# Epoch 92/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0136 - val_sparse_categorical_accuracy: 0.9978
# Epoch 93/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0169 - val_sparse_categorical_accuracy: 0.9979
# Epoch 94/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 0.9983
# Epoch 95/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9978
# Epoch 96/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0129 - val_sparse_categorical_accuracy: 0.9981
# Epoch 97/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0082 - val_sparse_categorical_accuracy: 0.9978
# Epoch 98/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 0.9980
# Epoch 99/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 0.9980
# Epoch 100/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0165 - val_sparse_categorical_accuracy: 0.9979
# Model training finished
# Evaluating the model on the test data...
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0138 - sparse_categorical_accuracy: 0.9971
# Test accuracy: 99.71%
# 184/184 [==============================] - 2s 1ms/step
# Accuracy: 0.9971
# Precision: 0.9983
# Recall: 0.9959
# F1 Score: 0.9971
# Total Training Time: 101.65792107582092 seconds
#
# Fold 2:
# Start training the model...
# Epoch 1/100
# 160/160 [==============================] - 13s 14ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0202 - val_sparse_categorical_accuracy: 0.9984
# Epoch 2/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 0.9983
# Epoch 3/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 0.9981
# Epoch 4/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0088 - val_sparse_categorical_accuracy: 0.9979
# Epoch 5/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9986
# Epoch 6/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0076 - val_sparse_categorical_accuracy: 0.9984
# Epoch 7/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0133 - val_sparse_categorical_accuracy: 0.9982
# Epoch 8/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0063 - val_sparse_categorical_accuracy: 0.9983
# Epoch 9/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0059 - val_sparse_categorical_accuracy: 0.9982
# Epoch 10/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0095 - val_sparse_categorical_accuracy: 0.9980
# Epoch 11/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0159 - val_sparse_categorical_accuracy: 0.9980
# Epoch 12/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0076 - val_sparse_categorical_accuracy: 0.9983
# Epoch 13/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0103 - val_sparse_categorical_accuracy: 0.9981
# Epoch 14/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0165 - val_sparse_categorical_accuracy: 0.9983
# Epoch 15/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9980
# Epoch 16/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 0.9987
# Epoch 17/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0261 - val_sparse_categorical_accuracy: 0.9977
# Epoch 18/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0099 - val_sparse_categorical_accuracy: 0.9982
# Epoch 19/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0208 - val_sparse_categorical_accuracy: 0.9981
# Epoch 20/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 0.9977
# Epoch 21/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0121 - val_sparse_categorical_accuracy: 0.9981
# Epoch 22/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0105 - val_sparse_categorical_accuracy: 0.9981
# Epoch 23/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0133 - val_sparse_categorical_accuracy: 0.9980
# Epoch 24/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9985
# Epoch 25/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0068 - val_sparse_categorical_accuracy: 0.9986
# Epoch 26/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0089 - val_sparse_categorical_accuracy: 0.9984
# Epoch 27/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 0.9980
# Epoch 28/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0135 - val_sparse_categorical_accuracy: 0.9980
# Epoch 29/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0261 - val_sparse_categorical_accuracy: 0.9979
# Epoch 30/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0113 - val_sparse_categorical_accuracy: 0.9985
# Epoch 31/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0200 - val_sparse_categorical_accuracy: 0.9983
# Epoch 32/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0278 - val_sparse_categorical_accuracy: 0.9982
# Epoch 33/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0235 - val_sparse_categorical_accuracy: 0.9982
# Epoch 34/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0223 - val_sparse_categorical_accuracy: 0.9984
# Epoch 35/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0204 - val_sparse_categorical_accuracy: 0.9979
# Epoch 36/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0107 - val_sparse_categorical_accuracy: 0.9986
# Epoch 37/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0265 - val_sparse_categorical_accuracy: 0.9986
# Epoch 38/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 0.9983
# Epoch 39/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0229 - val_sparse_categorical_accuracy: 0.9986
# Epoch 40/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0243 - val_sparse_categorical_accuracy: 0.9987
# Epoch 41/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0228 - val_sparse_categorical_accuracy: 0.9980
# Epoch 42/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 0.9987
# Epoch 43/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0191 - val_sparse_categorical_accuracy: 0.9985
# Epoch 44/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 0.9986
# Epoch 45/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0216 - val_sparse_categorical_accuracy: 0.9982
# Epoch 46/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0123 - val_sparse_categorical_accuracy: 0.9983
# Epoch 47/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0279 - val_sparse_categorical_accuracy: 0.9983
# Epoch 48/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0202 - val_sparse_categorical_accuracy: 0.9987
# Epoch 49/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0208 - val_sparse_categorical_accuracy: 0.9981
# Epoch 50/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0142 - val_sparse_categorical_accuracy: 0.9986
# Epoch 51/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0218 - val_sparse_categorical_accuracy: 0.9986
# Epoch 52/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0135 - val_sparse_categorical_accuracy: 0.9982
# Epoch 53/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 0.9981
# Epoch 54/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0246 - val_sparse_categorical_accuracy: 0.9981
# Epoch 55/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9983
# Epoch 56/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 0.9985
# Epoch 57/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9983
# Epoch 58/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0225 - val_sparse_categorical_accuracy: 0.9984
# Epoch 59/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0171 - val_sparse_categorical_accuracy: 0.9987
# Epoch 60/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 0.9986
# Epoch 61/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0261 - val_sparse_categorical_accuracy: 0.9986
# Epoch 62/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 0.9986
# Epoch 63/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 0.9986
# Epoch 64/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0265 - val_sparse_categorical_accuracy: 0.9986
# Epoch 65/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0197 - val_sparse_categorical_accuracy: 0.9986
# Epoch 66/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0149 - val_sparse_categorical_accuracy: 0.9983
# Epoch 67/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0287 - val_sparse_categorical_accuracy: 0.9983
# Epoch 68/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 0.9983
# Epoch 69/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0316 - val_sparse_categorical_accuracy: 0.9979
# Epoch 70/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0258 - val_sparse_categorical_accuracy: 0.9981
# Epoch 71/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9979
# Epoch 72/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0162 - val_sparse_categorical_accuracy: 0.9979
# Epoch 73/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0116 - val_sparse_categorical_accuracy: 0.9979
# Epoch 74/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0198 - val_sparse_categorical_accuracy: 0.9983
# Epoch 75/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0210 - val_sparse_categorical_accuracy: 0.9980
# Epoch 76/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0123 - val_sparse_categorical_accuracy: 0.9986
# Epoch 77/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 0.9983
# Epoch 78/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0261 - val_sparse_categorical_accuracy: 0.9985
# Epoch 79/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 0.9983
# Epoch 80/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0299 - val_sparse_categorical_accuracy: 0.9983
# Epoch 81/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 0.9980
# Epoch 82/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 0.9984
# Epoch 83/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0242 - val_sparse_categorical_accuracy: 0.9986
# Epoch 84/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9984
# Epoch 85/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0274 - val_sparse_categorical_accuracy: 0.9984
# Epoch 86/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9980
# Epoch 87/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0290 - val_sparse_categorical_accuracy: 0.9983
# Epoch 88/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0293 - val_sparse_categorical_accuracy: 0.9983
# Epoch 89/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0328 - val_sparse_categorical_accuracy: 0.9983
# Epoch 90/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0350 - val_sparse_categorical_accuracy: 0.9982
# Epoch 91/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0281 - val_sparse_categorical_accuracy: 0.9980
# Epoch 92/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 0.9983
# Epoch 93/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0164 - val_sparse_categorical_accuracy: 0.9982
# Epoch 94/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9980
# Epoch 95/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 0.9979
# Epoch 96/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0314 - val_sparse_categorical_accuracy: 0.9980
# Epoch 97/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0243 - val_sparse_categorical_accuracy: 0.9980
# Epoch 98/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9983
# Epoch 99/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0137 - val_sparse_categorical_accuracy: 0.9984
# Epoch 100/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0119 - val_sparse_categorical_accuracy: 0.9981
# Model training finished
# Evaluating the model on the test data...
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9974
# Test accuracy: 99.74%
# 184/184 [==============================] - 1s 976us/step
# Accuracy: 0.9974
# Precision: 0.9973
# Recall: 0.9976
# F1 Score: 0.9974
# Total Training Time: 100.04366660118103 seconds
#
# Fold 3:
# Start training the model...
# Epoch 1/100
# 160/160 [==============================] - 13s 14ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0064 - val_sparse_categorical_accuracy: 0.9979
# Epoch 2/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0035 - val_sparse_categorical_accuracy: 0.9981
# Epoch 3/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.9982
# Epoch 4/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9982
# Epoch 5/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.9982
# Epoch 6/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9982
# Epoch 7/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9984
# Epoch 8/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9984
# Epoch 9/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.9982
# Epoch 10/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9986
# Epoch 11/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.9982
# Epoch 12/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9982
# Epoch 13/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.9982
# Epoch 14/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9984
# Epoch 15/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 0.9986
# Epoch 16/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9983
# Epoch 17/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9984
# Epoch 18/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9984
# Epoch 19/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.9984
# Epoch 20/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9984
# Epoch 21/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9984
# Epoch 22/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9984
# Epoch 23/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9984
# Epoch 24/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9984
# Epoch 25/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.9984
# Epoch 26/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9984
# Epoch 27/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9987
# Epoch 28/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9987
# Epoch 29/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.9985
# Epoch 30/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9984
# Epoch 31/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 0.9982
# Epoch 32/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9982
# Epoch 33/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9984
# Epoch 34/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9982
# Epoch 35/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9982
# Epoch 36/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9982
# Epoch 37/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9982
# Epoch 38/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.9981
# Epoch 39/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.9982
# Epoch 40/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9982
# Epoch 41/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9982
# Epoch 42/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.9982
# Epoch 43/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9984
# Epoch 44/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9983
# Epoch 45/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 0.9983
# Epoch 46/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9982
# Epoch 47/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9982
# Epoch 48/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9983
# Epoch 49/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9985
# Epoch 50/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.9982
# Epoch 51/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9982
# Epoch 52/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9985
# Epoch 53/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 0.9987
# Epoch 54/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9983
# Epoch 55/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.9984
# Epoch 56/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.9984
# Epoch 57/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.9983
# Epoch 58/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.9984
# Epoch 59/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 0.9987
# Epoch 60/100
# ...
# Epoch 60/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 0.9984
# Epoch 61/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0107 - val_sparse_categorical_accuracy: 0.9983
# Epoch 62/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0101 - val_sparse_categorical_accuracy: 0.9985
# Epoch 63/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 0.9985
# Epoch 64/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0144 - val_sparse_categorical_accuracy: 0.9984
# Epoch 65/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 0.9985
# Epoch 66/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 0.9984
# Epoch 67/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0063 - val_sparse_categorical_accuracy: 0.9985
# Epoch 68/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9985
# Epoch 69/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0114 - val_sparse_categorical_accuracy: 0.9983
# Epoch 70/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0086 - val_sparse_categorical_accuracy: 0.9984
# Epoch 71/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 0.9981
# Epoch 72/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0089 - val_sparse_categorical_accuracy: 0.9982
# Epoch 73/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 0.9984
# Epoch 74/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 0.9983
# Epoch 75/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9981
# Epoch 76/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0097 - val_sparse_categorical_accuracy: 0.9977
# Epoch 77/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 0.9980
# Epoch 78/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0105 - val_sparse_categorical_accuracy: 0.9980
# Epoch 79/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 0.9978
# Epoch 80/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0102 - val_sparse_categorical_accuracy: 0.9984
# Epoch 81/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 0.9979
# Epoch 82/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9981
# Epoch 83/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9983
# Epoch 84/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0089 - val_sparse_categorical_accuracy: 0.9984
# Epoch 85/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0097 - val_sparse_categorical_accuracy: 0.9979
# Epoch 86/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0124 - val_sparse_categorical_accuracy: 0.9983
# Epoch 87/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9983
# Epoch 88/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 0.9982
# Epoch 89/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 0.9984
# Epoch 90/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 0.9983
# Epoch 91/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0143 - val_sparse_categorical_accuracy: 0.9985
# Epoch 92/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 0.9984
# Epoch 93/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0103 - val_sparse_categorical_accuracy: 0.9985
# Epoch 94/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0107 - val_sparse_categorical_accuracy: 0.9982
# Epoch 95/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9981
# Epoch 96/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0145 - val_sparse_categorical_accuracy: 0.9977
# Epoch 97/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0107 - val_sparse_categorical_accuracy: 0.9985
# Epoch 98/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 0.9983
# Epoch 99/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0084 - val_sparse_categorical_accuracy: 0.9985
# Epoch 100/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 0.9986
# Model training finished
# Evaluating the model on the test data...
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0090 - sparse_categorical_accuracy: 0.9986
# Test accuracy: 99.86%
# 184/184 [==============================] - 2s 1ms/step
# Accuracy: 0.9986
# Precision: 0.9993
# Recall: 0.9980
# F1 Score: 0.9986
# Total Training Time: 96.35799050331116 seconds
#
# Fold 10:
# Start training the model...
# Epoch 1/100
# 160/160 [==============================] - 14s 14ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 0.9982
# Epoch 2/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9982
# Epoch 3/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 0.9982
# Epoch 4/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0175 - val_sparse_categorical_accuracy: 0.9981
# Epoch 5/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0162 - val_sparse_categorical_accuracy: 0.9981
# Epoch 6/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 0.9980
# Epoch 7/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 0.9976
# Epoch 8/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0131 - val_sparse_categorical_accuracy: 0.9976
# Epoch 9/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 0.9977
# Epoch 10/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 0.9974
# Epoch 11/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 0.9979
# Epoch 12/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0152 - val_sparse_categorical_accuracy: 0.9980
# Epoch 13/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0087 - val_sparse_categorical_accuracy: 0.9981
# Epoch 14/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0104 - val_sparse_categorical_accuracy: 0.9979
# Epoch 15/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0089 - val_sparse_categorical_accuracy: 0.9980
# Epoch 16/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0123 - val_sparse_categorical_accuracy: 0.9979
# Epoch 17/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9976
# Epoch 18/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 0.9973
# Epoch 19/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0128 - val_sparse_categorical_accuracy: 0.9976
# Epoch 20/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 0.9975
# Epoch 21/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 0.9971
# Epoch 22/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0190 - val_sparse_categorical_accuracy: 0.9973
# Epoch 23/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 0.9980
# Epoch 24/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0146 - val_sparse_categorical_accuracy: 0.9982
# Epoch 25/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9975
# Epoch 26/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0159 - val_sparse_categorical_accuracy: 0.9975
# Epoch 27/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0119 - val_sparse_categorical_accuracy: 0.9976
# Epoch 28/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 0.9973
# Epoch 29/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0151 - val_sparse_categorical_accuracy: 0.9975
# Epoch 30/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 0.9972
# Epoch 31/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0135 - val_sparse_categorical_accuracy: 0.9974
# Epoch 32/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0143 - val_sparse_categorical_accuracy: 0.9978
# Epoch 33/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 0.9975
# Epoch 34/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 0.9976
# Epoch 35/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 0.9975
# Epoch 36/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0113 - val_sparse_categorical_accuracy: 0.9979
# Epoch 37/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0144 - val_sparse_categorical_accuracy: 0.9973
# Epoch 38/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9977
# Epoch 39/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0116 - val_sparse_categorical_accuracy: 0.9974
# Epoch 40/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0104 - val_sparse_categorical_accuracy: 0.9981
# Epoch 41/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9973
# Epoch 42/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0165 - val_sparse_categorical_accuracy: 0.9974
# Epoch 43/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 0.9977
# Epoch 44/100
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 0.9973
# Epoch 45/100
#  93/160 [================>.............] - ETA: 0s - loss: 0.0024 - sparse_categorical_accuracy: 0.9990
